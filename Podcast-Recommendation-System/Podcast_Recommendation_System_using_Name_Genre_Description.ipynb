# %%
#importing the dependecies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#loading the dataset into the workspace
data = pd.read_csv('poddf.csv')
data.head()
# Out:
#    index                            Name Rating_Volume   Rating       Genre  \
# 0      0                       Fresh Air         10188  4.46133        Arts
# 1      1                        The Moth         10154  4.69982  Performing
# 2      2                   99% Invisible         12303   4.8693      Design
# 3      3  iFanboy.com Comic Book Podcast          1335  4.79551      Visual
# 4      4               Myths and Legends         11128  4.88282  Literature
#
#                                          Description
# 0  Fresh Air from WHYY, the Peabody Award-winning...
# 1  Since its launch in 1997, The Moth has present...
# 2  Design is everywhere in our lives, perhaps mos...
# 3  The iFanboy.com Comic Book Podcast is a weekly...
# 4  Jason Weiser tells stories from myths, legends...

# %%
podcast = data[['Name','Genre','Description']]
podcast.head()
# Out:
#                              Name       Genre  \
# 0                       Fresh Air        Arts
# 1                        The Moth  Performing
# 2                   99% Invisible      Design
# 3  iFanboy.com Comic Book Podcast      Visual
# 4               Myths and Legends  Literature
#
#                                          Description
# 0  Fresh Air from WHYY, the Peabody Award-winning...
# 1  Since its launch in 1997, The Moth has present...
# 2  Design is everywhere in our lives, perhaps mos...
# 3  The iFanboy.com Comic Book Podcast is a weekly...
# 4  Jason Weiser tells stories from myths, legends...

# %%
podcast.shape
# Out:
# (13632, 3)

# %%
combine_features = data['Name'] + ' ' + data['Genre'] + ' ' + data['Description']

# %%
print(combine_features)
# Out:
# 0        Fresh Air Arts Fresh Air from WHYY, the Peabod...
# 1        The Moth Performing Since its launch in 1997, ...
# 2        99% Invisible Design Design is everywhere in o...
# 3        iFanboy.com Comic Book Podcast Visual The iFan...
# 4        Myths and Legends Literature Jason Weiser tell...
#                                ...
# 13627    Puromac Tech News Puromac es una conversación ...
# 13628    AVexcel Tech News AVexcel is your guide to the...
# 13629    Take a Network Break And Get The Latest Networ...
# 13630    AVexcel Tech News AVexcel is your guide to the...
# 13631    Take a Network Break And Get The Latest Networ...
# Length: 13632, dtype: object

# %%
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combine_features)

# %%
similarity = cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.03788201 0.06123121 ... 0.01265802 0.01258005 0.01265802]
#  [0.03788201 1.         0.03762742 ... 0.04220054 0.01630242 0.04220054]
#  [0.06123121 0.03762742 1.         ... 0.01621951 0.0209209  0.01621951]
#  ...
#  [0.01265802 0.04220054 0.01621951 ... 1.         0.08363158 1.        ]
#  [0.01258005 0.01630242 0.0209209  ... 0.08363158 1.         0.08363158]
#  [0.01265802 0.04220054 0.01621951 ... 1.         0.08363158 1.        ]]

# %%
import difflib
podcast_Name = str(input('Enter the name of your favorite podcast : '))
list_of_all_names = data['Name'].tolist()
find_close_match = difflib.get_close_matches(podcast_Name, list_of_all_names)
print(find_close_match)
# Out:
# ['Millennial']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Millennial

# %%
index_of_the_podcast_name = data[data['Name'] == close_match]['index'].values[0]
print(index_of_the_podcast_name)
# Out:
# 10541

# %%
similarity_score = list(enumerate(similarity[index_of_the_podcast_name]))

# %%
sorted_similar_podcast_name = sorted(similarity_score, key = lambda x:x[1], reverse = True) 
print(sorted_similar
589189535), (10852, 0.06375225860444701), (10839, 0.06366792918144137), (90, 0.06357253402402174), (1798, 0.06357238688628798), (6465, 0.06336366115163213), (5861, 0.06335419050234029), (4031, 0.06326610579501332), (10879, 0.06322901366564895), (4333, 0.0632167448687583), (10822, 0.06310810396534787), (2238, 0.06303594689837497), (12711, 0.06291037091548154), (2164, 0.06283250974795326), (7472, 0.06282509461002478), (10142, 0.06264837323630895), (1648, 0.06259224152647733), (633, 0.06257048304684101), (1764, 0.062418522443805066), (5942, 0.06239438978168413), (4209, 0.06221398456674748), (13191, 0.06199728185931126), (10834, 0.061838268334276636), (2155, 0.061819 ...

# %%
print('Podcast recommended for you : \n')

i = 1

for name in sorted_similar_podcast_name:
  index = name[0]
  title_from_index = data[data.index==index]['Name'].values[0]
  if (i<10):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Podcast recommended for you :
#
# 1 . Millennial
# 2 . The Allusionist
# 3 . Benjamen Walker's Theory of Everything
# 4 . The Heart
# 5 . The Mortified Podcast
# 6 . 99% Invisible
# 7 . Love + Radio
# 8 . Radio Diaries
# 9 . the memory palace

# %% [markdown]
# <h2 align='center'>| FINAL PODCAST RECOMMENDATION SYSTEM |</h2>

# %%
podcast_Name = input(' Enter your favourite podcast name : ')

list_of_all_names = data['Name'].tolist()

find_close_match = difflib.get_close_matches(podcast_Name, list_of_all_names)

close_match = find_close_match[0]

index_of_the_podcast_name = data[data.Name == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_podcast_name]))

sorted_similar_podcast_name = sorted(similarity_score, key = lambda x:x[1], reverse = True) 

print('Podcast recommended for you : \n')

i = 1

for movie in sorted_similar_podcast_name:
    index = movie[0]
    title_from_index = data[data.index==index]['Name'].values[0]
    if (i<30):
        print(i, '.',title_from_index)
        i+=1
# Out:
# Podcast recommended for you :
#
# 1 . The Tim Ferriss Show
# 2 . Tribe of Mentors
# 3 . The Random Show Podcast
# 4 . TNT PODCAST
# 5 . Pro Tools Expert Podcast
# 6 . The Random Show Podcast: Audio
# 7 . Waking Up with Sam Harris
# 8 . The Kevin Rose Show
# 9 . Noah Kagan Presents
# 10 . Perpetual Chess Podcast
# 11 . Chess Is Cool Podcast with Alexandra Kosteniuk
# 12 . PE's Chess Cast
# 13 . Rich Dad Radio Show: In-Your-Face Advice on Investing, Personal Finance, & Starting a Business
# 14 . Outperform
# 15 . The Anxiety Podcast
# 16 . From Pixels to Print – a graphic design discussion
# 17 . SECRETS TO REAL ESTATE INVESTING SHOW | HOUSE FLIPPING | CASH FLOW | INVESTING | LANDLORD
# 18 . CMS Media Calls
# 19 . Chess Killer Tips Video Podcast with Alexandra Kosteniuk
# 20 . The Less Doing Podcast with Ari Meisel: The Best Life Hacks And Productivity Tips For Less Doing, More Living
# 21 . The Cashflow Academy Show
# 22 . Paul Merriman
# 23 . Real Estate Investing For Women
# 24 . Best Real Estate Investing Advice Ever with Joe Fairless
# 25 . Chess.com Podcast
# 26 . Elite Man Podcast | Confidence | Psychology | Biohacking | Dating Advice | Men's Fashion | Relationship | Style | Productivit
# 27 . Internet Marketing: Insider Tips and Advice for Online Marketing
# 28 . The Create Your Own Life Show| Break the Chains of Ordinary, Become World-Class
# 29 . Invested: The Rule #1 Investing Podcast
